# %%
import geopandas as gpd
from shapely import wkt
import pandas as pd
import networkx as nx
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
diensten = gpd.read_file('overheid/overheidsdiensten.gml')
diensten.plot()

# %%
diensten = diensten[['activiteitOmschrijving','geometry']]
# diensten.loc[diensten['activiteitOmschrijving'] == "Basisonderwijs voor leerplichtigen"].plot()

# %%
nl = gpd.read_file('nl2/Gemeentegrenzen_2019.shp')
base = nl.plot( color='white', edgecolor='black',figsize=(12,12))

# %%
# diensten.plot(ax=base,figsize=(12,12));
diensten.plot()

# %%
import contextily as ctx
diensten = diensten.dropna()
diensten = diensten.to_crs(epsg=3857)
base = nl.to_crs(epsg=3857).plot()
# ctx.add_basemap(ax= diensten)
diensten
# Out:
#                                  activiteitOmschrijving  \
# 1                             Algemeen overheidsbestuur
# 2     Preventieve gezondheidszorg (geen arbobegeleid...
# 3                                             Brandweer
# 4                  Ambulancediensten en centrale posten
# 5                             Algemeen overheidsbestuur
# 6                                             Brandweer
# 7                                             Brandweer
# 8                                             Brandweer
# 9                                             Brandweer
# 10                                            Brandweer
# 11                                            Brandweer
# 12    Openbaar bestuur op het gebied van gezondheids...
# 13                                            Brandweer
# 14                            Algemeen overheidsbestuur
# 15    Openbaar bestuur op het gebied van gezondheids...
# 16    Openbaar bestuur op het gebied van gezondheids...
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
cmap = plt.cm.get_cmap('Dark2', 9)
ax = diensten.plot(c=diensten.activiteitOmschrijving 	, cmap=cmap, label=diensten.activiteitOmschrijving, figsize=(10,10), alpha=.5)
ctx.add_basemap(ax, source=ctx.providers.Stamen.TonerLite)
ax.set_axis_off()
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
